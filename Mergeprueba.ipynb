# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv("output/limpiezadf.csv")
df=df.head(50)
df
# Out:
#     Unnamed: 0                                                App Category  \
# 0        10776                                   Monster Ride Pro     GAME
# 1         9265                                           EC Mover     GAME
# 2        10721                                  Mad Dash Fo' Cash     GAME
# 3         5795                                   Axe Champs! Wars     GAME
# 4         5822        Flippy Axe : Flip The Knife & Axe Simulator     GAME
# 5         6700                                   Brick Breaker BR     GAME
# 6         7402                               Trovami se ci riesci     GAME
# 7         7698                                          CP Trivia     GAME
# 8         4975                      Solitaire: Decked Out Ad Free     GAME
# 9         6495                                          Word Hunt     GAME
# 10        8172                     Dan the Man: Action Platformer     GAME
# ...

# %%
api = pd.read_csv("output/limpiezaApi.csv")
api
# Out:
#     Unnamed: 0                                                 id  \
# 0            0  athena.studio.woody.sudoku.block.puzzle.brain....
# 1            1                                       com.braindom
# 2            2                                  com.parkour.swing
# 3            3                                  com.roblox.client
# 4            4                                com.HutsKoen.Kaasje
# 5            5                          com.innersloth.spacemafia
# 6            6                              com.demin.emojipuzzle
# 7            7                            com.jellybtn.boardkings
# 8            8                               com.kiloo.subwaysurf
# 9            9                                 com.gpg.ninemonths
# 10          10                    com.tapenjoy.minigame.aovstower
# 11          11                  com.tilemaster.puzzle.block.match
# 12          12                                    com.pizza.dough
# ...

# %%
df['App']=[str(x) for x in df['App']]

# %%
type(df.App)
# Out:
# pandas.core.series.Series

# %%
type(api.name)
# Out:
# pandas.core.series.Series

# %%
rating_change = pd.merge(left=df,right=api, how="left", left_on="name", right_on="App")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-6007fad14a46> in <module>
# ----> 1 rating_change = pd.merge(left=df,right=api, how="left", left_on="name", right_on="App")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...
